# %%
#Lybraries
import numpy as np
import os
import re
import matplotlib.pyplot as plt

# %%
#settings for plots

#tableau for plots
plt.style.use('tableau-colorblind10')

plt.rcParams["figure.autolayout"] = True

plt.rcParams['font.size'] = 16        # Default font size for text
plt.rcParams['axes.titlesize'] = 16   # Font size for axes titles
plt.rcParams['axes.labelsize'] = 16   # Font size for x and y labels
plt.rcParams['xtick.labelsize'] = 16  # Font size for x tick labels
plt.rcParams['ytick.labelsize'] = 16  # Font size for y tick labels

# %%
#folders and files
folder = 'placeholder/'
files = os.listdir(folder+'simulations/')

# %%
#hyperparameters
N = 400
N_steps = 61000
N_cut = 1000
dt = 0.05 
tau_m = 3 #ms
time = np.arange(0,N_steps*dt,dt)*tau_m
n_bins = 20

mu = 0.6
sigma = 0.6

# %%
files
# Out:
# ['sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.2_n6_index29.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.2_n5_index26.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.4_n0_index32.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.2_n5_index27.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.2_n6_index28.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.2_n7_index31.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.2_n7_index30.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.0_n1_index3.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.4_n0_index33.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.2_n4_index25.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.2_n0_index16.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.0_n5_index11.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.0_n0_index0.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.0_n0_index1.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.0_n2_index5.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.0_n3_index7.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.0_n3_index6.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.0_n2_index4.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.0_n1_index2.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.0_n4_index9.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.0_n4_index8.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.0_n7_index15.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.0_n5_index10.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.0_n6_index13.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.0_n6_index12.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.0_n7_index14.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.2_n0_index17.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.2_n1_index18.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.2_n1_index19.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.2_n2_index21.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.2_n2_index20.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.2_n3_index22.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.2_n3_index23.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.2_n4_index24.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.4_n2_index37.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.4_n4_index41.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.4_n1_index35.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.4_n3_index39.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.4_n1_index34.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.4_n4_index40.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.4_n3_index38.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.4_n2_index36.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.4_n5_index43.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.4_n5_index42.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.6_n0_index49.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.4_n6_index44.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.4_n7_index47.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.4_n6_index45.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.6_n0_index48.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.4_n7_index46.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.6_n1_index51.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.6_n1_index50.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.6_n2_index53.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.6_n2_index52.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.6_n3_index54.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.6_n3_index55.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.6_n4_index56.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.6_n4_index57.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.6_n5_index59.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.6_n5_index58.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.6_n6_index61.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.6_n7_index63.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.6_n6_index60.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.8_n0_index64.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.8_n0_index65.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.6_n7_index62.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.8_n1_index67.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.8_n1_index66.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.8_n2_index69.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.8_n2_index68.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.8_n3_index71.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.8_n4_index72.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.8_n4_index73.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.8_n3_index70.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.8_n5_index74.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.8_n5_index75.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.0_n0_index81.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.8_n7_index78.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.8_n6_index77.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.0_n0_index80.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g0.8_n6_index76.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g0.8_n7_index79.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.0_n1_index82.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.0_n1_index83.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.0_n4_index89.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.0_n2_index85.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.0_n3_index87.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.0_n4_index88.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.0_n2_index84.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.0_n3_index86.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.0_n5_index91.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.0_n5_index90.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.0_n6_index93.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.0_n6_index92.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.0_n7_index95.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.0_n7_index94.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.2_n0_index97.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1.2_n0_index96.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.2_n3_index103.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g1.2_n1_index99.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g1
npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g2.8_n7_index239.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g3.0_n0_index241.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g3.0_n1_index243.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g3.0_n4_index248.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g3.0_n3_index246.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g3.0_n2_index244.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g3.0_n1_index242.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g3.0_n2_index245.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g3.0_n3_index247.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g3.0_n7_index254.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g3.0_n6_index253.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g3.0_n4_index249.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g3.0_n5_index250.npz',
#  'sim_s_dist_homogeneous_muNone_sigmaNone_mean2.2_g3.0_n6_index252.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g3.0_n5_index251.npz',
#  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g3.0_n7_index255.npz']

# %%
#selcting simulations to whatc
n = np.random.randint(0,len(files))
file = files[n]
file
# Out:
# 'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g2.8_n0_index225.npz'

# %%
file =  'sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g2.0_n1_index163.npz'

# %%
#loading data
data = np.load(folder+'simulations/'+file)
sim = data['sim']
J = data['J']
S = data['S']
tau = data['tau']

# %%
#Plot of the simulation
plt.figure(figsize=(15,5))
plt.plot(time*10**(-3), sim.T)
#plt.title(file.split('.npz')[0])
print(file.split('.npz')[0])
plt.xlabel('Time [s]')
plt.ylabel('Activity x')
plt.show()
# Out:
# sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g2.4_n3_index199

# %%
#Plot distributions and scatter plot
# Set up the figure and the grid
fig = plt.figure(figsize=(11, 11))
grid = plt.GridSpec(4, 4, hspace=0.4, wspace=0.4)

# Define the axes
scatter_ax = fig.add_subplot(grid[1:4, 0:3])
x_hist_ax = fig.add_subplot(grid[0, 0:3], sharex=scatter_ax)
y_hist_ax = fig.add_subplot(grid[1:4, 3], sharey=scatter_ax)

# Scatter plot
scatter_ax.scatter(S, tau*tau_m, color='blue', alpha=0.6)
scatter_ax.set_xlabel(r'Size of the assemblies $s_i$')
scatter_ax.set_ylabel(r'Autocorrelation times $\tau_i$ [ms]')

# X histogram
x_hist_ax.hist(S, bins = n_bins, color='blue', alpha = 0.6, density = True)
x = np.linspace(0.1, 9, 1000)
x_hist_ax.plot(x, np.exp(-0.5*(np.log(x)-mu)**2/sigma**2)/np.sqrt(2*np.pi*sigma**2)/x, color = 'k')
x_hist_ax.set_xlabel(r'$s_i$')
x_hist_ax.set_ylabel(r'$P(s_i)$')


# Y histogram
y_hist_ax.hist(tau*tau_m, bins = n_bins, orientation='horizontal', color='blue', alpha = 0.6, density= True)
y_hist_ax.set_xlabel(r'$P(\tau_i$)')
y_hist_ax.set_ylabel(r'$\tau_i$')

#fig.suptitle(file.split('.npz')[0])
print(file.split('.npz')[0])

plt.savefig('final_results/ex_scatter_plot_het_s_g2.png', pad_inches=0.1, bbox_inches='tight')
# Out:
# sim_s_dist_heterogeneous_mu0.6_sigma0.6_meanNone_g2.0_n1_index163
# /tmp/ipykernel_20662/1104733643.py:32: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig('final_results/ex_scatter_plot_het_s_g2.png', pad_inches=0.1, bbox_inches='tight')
# /home/zenn/anaconda3/envs/VCS/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
