# %%
#Libraries
import numpy as np
import numba as nb
from joblib import Parallel, delayed
import random
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
# Integrator of GLV dynamics

#RK4
@nb.jit
def RK4_step(x_t, S, K, alpha, dt):

    k1 = rhs(x_t, S, K, alpha)
    k2 = rhs(x_t + dt/2 * k1, S, K, alpha)
    k3 = rhs(x_t + dt/2 * k2, S, K, alpha)
    k4 = rhs(x_t + dt * k3, S, K, alpha)
    
    return x_t + dt/6 * (k1 + 2*k2 + 2*k3 + k4)

@nb.jit
def rhs(x_t, S, K, alpha):
    f = np.zeros(S)
    for i in range(S):
        tmp = 0
        for j in range(S):
            tmp = tmp + alpha[i, j]* J(x_t[j], K)
    
        f[i] = x_t[i]*(1-x_t[i]+tmp)
    return f

@nb.jit
def RK4(S, alpha, K, timesteps, dt):
    x = np.zeros((S, timesteps))
    x[:, 0] = np.random.rand(S)
    for n in range(1, timesteps):
        x[:, n] = RK4_step(x[:, n-1], S, K, alpha, dt)
    return x


def inter_matrix(N, mu, sigma, gamma):
#covariance matrix and mean for sampling          
    alpha = np.zeros([N, N]) #matrix of interactions

    for i in range(N):
        for j in range(i+1, N):
            z = np.random.normal(size = 2)
            alpha[i, j] = mu/N+sigma/np.sqrt(N)*z[0]
            alpha[j, i] = mu/N+sigma/np.sqrt(N)*(gamma*z[0]+np.sqrt(1-gamma**2)*z[1])

    return alpha


@nb.njit
def J(x, K):
    return x/(1+K*x)


#task
def simulation(par):
    
    [S, mu, sigma, gamma, K, i] = par
       

    alpha = inter_matrix(S, mu, sigma, gamma)
    run1 = RK4(S, alpha, K, timesteps, dt)
    run2 = RK4(S, alpha, K, timesteps, dt)
    
    stat1 = run1[:, N_cut:]
    stat2 = run2[:, N_cut:]

    fold1 = 'S{}/'.format(S)
    fold2 = 'mu{}_sigma{}_gamma{}_K{}/'.format(mu, sigma, gamma, K)
    filename =  'mu{}_sigma{}_gamma{}_K{}_iter{}'.format(mu, sigma, gamma, K, i)       

    if SAVE_SIM:
        np.savez(path_to_save_sim+fold0+fold1+fold2+filename, alpha = alpha, run1=run1, run2=run2)
    
    if SAVE_STAT:
        np.savez(path_to_save_stat+fold0+fold1+fold2+filename, stat1=stat1, stat2=stat2)

        
    new_row = [S, mu, sigma, gamma, K]

    return new_row

# %%
#Parameters lists
S_list = [200]
mu_list = [-3]
sigma_list = [2.5, 2.7, 3.1, 3.3, 2.9, 2.3, 3.5, 3.7, 2.1]
gamma_list = [-0.5]
K_list = [0.1]

# %%
# Simulation parameters
N_sam = 20 #number of sampling of interaction matrix
dt = 0.005
timesteps = 40_000
N_cut = int(timesteps*0.95) #time to consider for equilibration

# %%
# Data output 
SAVE_SIM = True
path_to_save_sim = 'placeholder/'

SAVE_STAT = True 
path_to_save_stat = 'placeholder/'

# %%
# Create folders to store data and parammeters list
fold0 = 'data_critical_line_N_sam{}_dt{}_timesteps{}_N_cut{}/'.format(N_sam, dt, timesteps, N_cut)

if SAVE_SIM:
    os.mkdir(path_to_save_sim+fold0)

if SAVE_STAT:
    os.mkdir(path_to_save_stat+fold0)


parameters = []

for S in S_list:
    fold1='S{}/'.format(S)

    if SAVE_SIM:
        os.mkdir(path_to_save_sim+fold0+fold1)

    if SAVE_STAT:
        os.mkdir(path_to_save_stat+fold0+fold1)

    for mu in mu_list:
        for sigma in sigma_list:
            for gamma in gamma_list:
                for K in K_list:
                    fold2 = 'mu{}_sigma{}_gamma{}_K{}/'.format(mu, sigma, gamma, K)
                    if SAVE_SIM:
                        os.mkdir(path_to_save_sim+fold0+fold1+fold2)

                    if SAVE_STAT:
                        os.mkdir(path_to_save_stat+fold0+fold1+fold2)

                    for i in range(N_sam):
                        parameters.append([S, mu, sigma, gamma, K, i])

# %%
#Phase diagram simulations
print('Number of tasks:', len(parameters))
data = Parallel(n_jobs = -1, verbose = 11)(delayed(simulation)(par) for par in parameters)
# Out:
# Number of tasks: 180
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 22.3min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 22.6min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 23.9min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 23.9min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 24.8min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 25.4min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 26.3min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 26.4min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 27.2min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 27.5min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 29.0min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 29.1min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 29.2min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 30.6min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 30.8min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 31.3min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 31.4min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 31.4min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 31.5min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 31.6min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 31.7min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 33.1min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 33.4min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 33.8min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 33.8min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 34.1min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 34.5min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 35.1min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 35.6min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 35.8min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 36.3min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 36.6min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 36.6min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 36.9min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 37.2min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 37.7min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 38.1min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 38.6min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 38.7min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 39.0min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed: 39.1min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 39.4min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed: 39.6min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed: 40.1min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed: 40.6min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed: 41.1min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed: 41.2min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed: 41.6min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed: 41.6min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 41.8min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed: 42.2min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed: 42.7min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed: 43.1min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed: 43.6min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed: 43.6min
# [Parallel(n_jobs